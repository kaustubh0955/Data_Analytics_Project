# %%
import pandas as pd

# %%
data=pd.read_csv("/content/drive/MyDrive/Complete_Reviews1.csv")
data.describe()
# Out:
#            Rating
# count  729.000000
# mean     4.480110
# std      1.274195
# min      1.000000
# 25%      5.000000
# 50%      5.000000
# 75%      5.000000
# max      5.000000

# %%
data.head()
# Out:
#              Author      Date  Rating  \
# 0           Lorri R  25/05/16     5.0
# 1  Sabrina Fountain  09/06/16     5.0
# 2      jason cooper  09/06/16     5.0
# 3        Russ Smith  13/06/16     5.0
# 4    Candace Lawson  17/06/16     5.0
#
#                                               Review    City
# 0  We have never had a problem with our service. ...  Boston
# 1  I am the manager at All Star Heavy Haul & Towi...  Boston
# 2  our driver don is the best always here on thus...  Boston
# 3                                                NaN  Boston
# 4  We have had Unifirst uniforms for some time no...  Boston

# %%
# @title Rating

from matplotlib import pyplot as plt
data['Rating'].plot(kind='hist', bins=20, title='Rating')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
count=1
for i in data["Review"]:
  if count==21:
    break
  else:
    print(f'\nReview:\t{i}')
    count+=1
# Out:
# Review:	We have never had a problem with our service.  John Miller is our agent that brings us our mats.  Thank you
#
# Review:	I am the manager at All Star Heavy Haul & Towing in Tracy, Ca.  My Unifirst-Stockton, Ca service rep Don is amazing, always polite and courteous and I will continue to use Unifirst.  They have great customer service in the office as well.  Highly recommend this company!!
#
# Review:	our driver don is the best always here on thus-day happy he always give his best service.we consider him family.no complaints here.
# jason cooper
#
# Review:	nan
#
# Review:	We have had Unifirst uniforms for some time now and each one of our experiences has been wonderful. Our current driver Keith is great and is always pleasant, on time and willing to help!
#
# Review:	Gilbert from the San Diego branch has been a huge help!
#
# Not only is he a good worker but he's also extremely friendly and reliable.
#
# Uni-First has definitely been a step up compared to our previous coat vendor.
#
# Review:	Jeremy C. does a fantastic job for Pre-Owned Commercial Trucks & Equipment
#
# Review:	We have the best driver, Jimmy. He provides top notch customer service. I do not have any complaints about our account. Anything I ever need is always handled in a timely manner. Very happy .
# Gwen
# Royalty Well Service, Inc.
#
# Review:	Great customer service
#
# Review:	I work for Tri Rotor at Hugoton Offices Floyd give us a excellent service
#
# Review:	always on time, always courteous helpful. Awesome customer service.
#
# Review:	we have our company in corpus Christi and are very pleased with
# Adan Garcia who always seems to very personable and pleasant while
# coming to our office and is very efficient.  Thank You so much for all you do.
#
# Review:	Always friendly love the staff. The clothes is great quality embroidery looks great!!
#
# Review:	I work at a John deere dealership in Falconer, NY and we have had the privilege to be working with the Unifirst Buffalo location for about 8 years now and we have had nothing but great service and hardley no problems at all. Everything is always on time, quick and correct. I definitely recommend everyone to try them out. You won't be disapointed!!!
#
# Review:	The customer service is great. Our guy, Erasmo Sanchez, is so friendly and kind.
#
# Review:	We switched to Unifirst about 11/2 yr ago and have been very pleased. Our uniforms are clean and if there is a problem with them our driver Beau always takes care of it. He always very pleasant and extremely punctual.
# Our old supplier would not clean our uniforms and somehow always had new hidden fees and had no idea where they came from. With Beau we always know whats going on and we feel like we can trust him and the company. We are very happy with his service and Unifirst glad we switched. Thanks Unifirst,
# Jana / Manager at Terry"s Lube & Oil
#
# Review:	J.R. Is an amazing worker i enjoy seeing him every Wednesday he always has delightful attitude and is always fun to talk to.
#
# Review:	I will have to say that I love your guy's service. I work at a convenience store, and I have to say that the delivery guy, Aaron, was very good. While I was working, he would be very patient around me, and he is very kind and always has a big smile when I see him. He is fast, communicative for our needs, and even greeted many of my customers. You guys have a good employee, and I hope you guys keep him around.
#
# Review:	Robin Blue is our Unifirst rep. She is fantastic and very courteous! They provide an excellent service for us!
#
# Review:	nan

# %%
data.shape
# Out:
# (735, 5)

# %%
data.dropna()
data.shape
# Out:
# (735, 5)

# %%
data["Review"].dtypes
# Out:
# dtype('O')

# %%
data.replace("NaN", pd.NA, inplace=True)

# Drop rows where any column has NaN values
data = data.dropna()
data.shape
# Out:
# (670, 5)

# %%
print(f'Reviews where no comments were made :{735-670}')
# Out:
# Reviews where no comments were made :65

# %%
from transformers import pipeline

distilled_student_sentiment_classifier = pipeline(
    model="lxyuan/distilbert-base-multilingual-cased-sentiments-student",
    return_all_scores=True
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/759 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/541M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/373 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.92M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py:105: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(

# %%
import math

# Define the maximum sequence length supported by the model
max_seq_length = 512  # or whatever the maximum sequence length is for your model

predicted_labels = []

# Iterate over inputs
for input_text in data["Review"]:
    # Split the input text into smaller segments if it exceeds the maximum sequence length
    input_segments = [input_text[i:i+max_seq_length] for i in range(0, len(input_text), max_seq_length)]

    # Iterate over each segment
    segment_predicted_labels = []
    for segment in input_segments:
        # Pass the input segment through the model
        output = distilled_student_sentiment_classifier(segment)

        # Extract the label with the highest score
        predicted_label = max(output[0], key=lambda x: x['score'])['label']
        segment_predicted_labels.append(predicted_label)

    # Combine the predicted labels for all segments
    combined_label = max(set(segment_predicted_labels), key=segment_predicted_labels.count)
    predicted_labels.append(combined_label)

# Print the list of predicted labels
print(predicted_labels)
# Out:
# ['positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'negative', 'positive', 'negative', 'positive', 'negative', 'negative', 'negative', 'positive', 'negative', 'positive', 'positive', 'positive', 'negative', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'negative', 'positive', 'negative', 'negative', 'positive', 'positive', 'negative', 'negative', 'positive', 'positive', 'positive', 'negative', 'positive', 'positive', 'negative', 'negative', 'negative', 'neutral', 'positive', 'positive', 'positive', 'positive', 'positive', 'negative', 'negative', 'positive', 'positive', 'positive', 'positive', 'negative', 'negative', 'negative', 'negative', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'negative', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'negative', 'negative', 'positive', 'negative', 'negative', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'negative', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'negative', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'negative', 'positive', 'positive', 'negative', 'negative', 'negative', 'positive', 'negative', 'negative', 'negative', 'positive', 'negative', 'negative', 'positive', 'positive', 'positive', 'positive', 'negative', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'negative', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'negative', 'negative', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'negative', 'positive', 'positive', 'positive', 'positive', 'positive', 'negative', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'negative', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'negative', 'negative', 'negative', 'negative', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'pos ...

# %%
len(predicted_labels)==data.shape[0]
# Out:
# True

# %%
counting=dict()
for i in predicted_labels:
  if i in counting:
    counting[i]+=1
  else:
    counting[i]=1
print(counting)
# Out:
# {'positive': 586, 'negative': 81, 'neutral': 3}

# %%
df_sentiment={"Sentiment":["Positive","Negative","Neutral"],
              "Numbers":[582,87,2]}
df_sentiment=pd.DataFrame(df_sentiment)
df_sentiment
# Out:
#   Sentiment  Numbers
# 0  Positive      582
# 1  Negative       87
# 2   Neutral        2

# %%
data["Sentiment"]=predicted_labels

# %%
data.head()
# Out:
#              Author      Date  Rating  \
# 0           Lorri R  25/05/16     5.0
# 1  Sabrina Fountain  09/06/16     5.0
# 2      jason cooper  09/06/16     5.0
# 4    Candace Lawson  17/06/16     5.0
# 5   Alberto Salgado  28/06/16     5.0
#
#                                               Review    City Sentiment
# 0  We have never had a problem with our service. ...  Boston  positive
# 1  I am the manager at All Star Heavy Haul & Towi...  Boston  positive
# 2  our driver don is the best always here on thus...  Boston  positive
# 4  We have had Unifirst uniforms for some time no...  Boston  positive
# 5  Gilbert from the San Diego branch has been a h...  Boston  positive

# %%
data[data['Sentiment'] == 'negative']
# Out:
#                Author                 Date  Rating  \
# 33      Steve Vigeant             31/10/16     1.0
# 35    Michael William             27/09/19     1.0
# 40                G.R             20/07/22     1.0
# 41            Munir K             28/12/23     1.0
# 42             Kyle G             05/11/13     1.0
# ..                ...                  ...     ...
# 718      Jeremy Cross  2021-01-19 00:34:43     5.0
# 730        Dawn Wildt  2023-01-06 13:37:32     1.0
# 732  Dominique Lamont  2023-04-29 19:15:12     1.0
# 733    Adria Anderson  2023-09-20 11:20:17     1.0
# 734      John Dushane  2024-01-08 09:23:51     1.0
#
#                                                 Review         City Sentiment
# 33   We have nothing but problems with this company...       Boston  negative
# 35   The service has been quite poor.  Please look ...       Boston  negative
# 40   Unprofessional, always late and missing unifor...       Boston  negative
# 41   Bunch of thieves… You’ll discover how they lit...       Boston  negative
# 42   Unifirst in Melrose Park, IL couldn't get anyt...      Chicago  negative
# ..                                                 ...          ...       ...
# 718  I ordered some custom shirts from Lucas and th...  Indianpolis  negative
# 730  Worst customer service ever. Repeatedly get bi...  Indianpolis  negative
# 732  I was just wrongfully terminated! Banner on th...  Indianpolis  negative
# 733  Unifirst has the worst customer service I have...  Indianpolis  negative
# 734  Do your homework before using this company. Th...  Indianpolis  negative
#
# [81 rows x 6 columns]

# %%
data["label"]=data['City']+'_'+data["Sentiment"]
data.head()
# Out:
#              Author      Date  Rating  \
# 0           Lorri R  25/05/16     5.0
# 1  Sabrina Fountain  09/06/16     5.0
# 2      jason cooper  09/06/16     5.0
# 4    Candace Lawson  17/06/16     5.0
# 5   Alberto Salgado  28/06/16     5.0
#
#                                               Review    City Sentiment  \
# 0  We have never had a problem with our service. ...  Boston  positive
# 1  I am the manager at All Star Heavy Haul & Towi...  Boston  positive
# 2  our driver don is the best always here on thus...  Boston  positive
# 4  We have had Unifirst uniforms for some time no...  Boston  positive
# 5  Gilbert from the San Diego branch has been a h...  Boston  positive
#
#              label
# 0  Boston_positive
# 1  Boston_positive
# 2  Boston_positive
# 4  Boston_positive
# 5  Boston_positive

# %%
data["label"] = data['Date'].astype(str) + '_' + data["Sentiment"]
data.head()
# Out:
#              Author      Date  Rating  \
# 0           Lorri R  25/05/16     5.0
# 1  Sabrina Fountain  09/06/16     5.0
# 2      jason cooper  09/06/16     5.0
# 4    Candace Lawson  17/06/16     5.0
# 5   Alberto Salgado  28/06/16     5.0
#
#                                               Review    City Sentiment  \
# 0  We have never had a problem with our service. ...  Boston  positive
# 1  I am the manager at All Star Heavy Haul & Towi...  Boston  positive
# 2  our driver don is the best always here on thus...  Boston  positive
# 4  We have had Unifirst uniforms for some time no...  Boston  positive
# 5  Gilbert from the San Diego branch has been a h...  Boston  positive
#
#                label
# 0  25/05/16_positive
# 1  09/06/16_positive
# 2  09/06/16_positive
# 4  17/06/16_positive
# 5  28/06/16_positive

# %%
import pandas as pd

# Assuming you have loaded your data into the DataFrame 'data'

# Extract year from the 'Date' column
data['Year'] = pd.to_datetime(data['Date']).dt.year.astype(str)

# Filter the DataFrame to include only reviews from 2018 and onwards
data = data[data['Year'].astype(int) >= 2018]

# Create the label by concatenating the year and sentiment
data["label"] = data['Year'] + '_' + data["Sentiment"]

# Drop the 'Year' column if it's no longer needed
data.drop(columns=['Year'], inplace=True)

data.head()
# Out:
# <ipython-input-21-ddfb61f0b6f9>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["label"] = data['Year'] + '_' + data["Sentiment"]
# <ipython-input-21-ddfb61f0b6f9>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(columns=['Year'], inplace=True)
#            Author      Date  Rating  \
# 18      Ken Quale  22/05/18     5.0
# 20       Nick Faz  07/10/19     5.0
# 21   Gyula Huszar  23/10/19     5.0
# 22     Ingrid Suy  02/12/19     5.0
# 23  Michael Allen  03/12/19     5.0
#
#                                                Review    City Sentiment  \
# 18  Robin Blue is our Unifirst rep. She is fantast...  Boston  positive
# 20  Service has been great since the beginning! Wa...  Boston  positive
# 21  I've been with UniFirst for the last 20 years ...  Boston  positive
# 22  I am the assistant manager of Applus Technolog...  Boston  positive
# 23  Mike is one of the most professional individua...  Boston  positive
#
#             label
# 18  2018_positive
# 20  2019_positive
# 21  2019_positive
# 22  2019_positive
# 23  2019_positive

# %%
# Step 2: Create a Mapping between Label and Unique IDs
label_to_id = {}  # Dictionary to map label to ID
current_id = 0

for label in data['label'].unique():
    label_to_id[label] = current_id
    current_id += 1
data['unique_id'] = data['label'].map(label_to_id)

# %%
data.tail()
# Out:
#                Author                 Date  Rating  \
# 730        Dawn Wildt  2023-01-06 13:37:32     1.0
# 731       Justin Hood  2023-03-11 23:16:44     1.0
# 732  Dominique Lamont  2023-04-29 19:15:12     1.0
# 733    Adria Anderson  2023-09-20 11:20:17     1.0
# 734      John Dushane  2024-01-08 09:23:51     1.0
#
#                                                 Review         City Sentiment  \
# 730  Worst customer service ever. Repeatedly get bi...  Indianpolis  negative
# 731  Terrible. I have till today to use my work all...  Indianpolis  positive
# 732  I was just wrongfully terminated! Banner on th...  Indianpolis  negative
# 733  Unifirst has the worst customer service I have...  Indianpolis  negative
# 734  Do your homework before using this company. Th...  Indianpolis  negative
#
#              label  unique_id
# 730  2023_negative          6
# 731  2023_positive          8
# 732  2023_negative          6
# 733  2023_negative          6
# 734  2024_negative         14

# %%
data['unique_id'].nunique()
# Out:
# 15

# %%
data["Sentiment"][731]="negative"
data["label"][731]="Indianpolis_negative"
data["unique_id"][731]=24
# Out:
# <ipython-input-25-60505b6d122c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["unique_id"][731]=24

# %%
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Step 1: Vectorize the 'Review' column using TF-IDF
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(data['Review'])

# %%
from collections import Counter

cluster_labels = {}

for unique_id, group_df in data.groupby('unique_id'):
    # Reset the index of group_df to ensure sequential indices
    group_df = group_df.reset_index(drop=True)

    # Check the number of samples in the group
    num_samples = len(group_df)

    if num_samples >= 3:  # Specify a minimum number of samples required for clustering
        # Apply K-means clustering to the TF-IDF vectors of reviews for each unique ID
        kmeans = KMeans(n_clusters=3,n_init=10, random_state=42)  # Specify the number of clusters
        group_df['cluster'] = kmeans.fit_predict(X[group_df.index])
    else:
        # If there are not enough samples for clustering, assign a single cluster to all samples
        group_df['cluster'] = [0] * num_samples

    # Assign cluster names based on the labels mapped to those IDs
    cluster_labels[unique_id] = group_df['label'].iloc[0]  # Take the label of the first row in the group

# Print cluster labels
print(cluster_labels)
# Out:
# {0: '2018_positive', 1: '2019_positive', 2: '2021_positive', 3: '2019_negative', 4: '2020_positive', 5: '2022_negative', 6: '2023_negative', 7: '2022_positive', 8: '2023_positive', 9: '2023_neutral', 10: '2020_negative', 11: '2021_negative', 12: '2018_negative', 13: '2024_positive', 14: '2024_negative', 24: 'Indianpolis_negative'}

# %%
from collections import Counter

# Initialize a Counter object to store the total TF-IDF scores for each term across all clusters
total_tfidf_scores = Counter()

# Assuming you have already performed clustering and have the cluster labels in the 'cluster' column of your DataFrame

# For each cluster
for cluster_idx, group_df in data.groupby('cluster'):
    # Get the TF-IDF vectors of the documents in this cluster
    cluster_X = X[group_df.index]

    # Sum up the TF-IDF scores for each term across all documents in the cluster
    total_tfidf_scores.update({feature_names[idx]: score for idx, score in zip(cluster_X.indices, cluster_X.data)})

    # Get the top N terms with the highest total TF-IDF scores
    top_terms = total_tfidf_scores.most_common(10)  # Adjust 10 to get more or fewer terms

    # Print the top terms for this cluster
    print(f"Cluster {cluster_idx} Top Terms: {', '.join(term for term, _ in top_terms)}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-5426df048dfa> in <cell line: 9>()
#       7
#       8 # For each cluster
# ----> 9 for cluster_idx, group_df in data.groupby('cluster'):
#      10     # Get the TF-IDF vectors of the documents in this cluster
#      11     cluster_X = X[group_df.index]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8400         axis = self._get_axis_number(axis)
#    8401
# -> 8402         return DataFrameGroupBy(
#    8403             obj=self,
#    8404             keys=by,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     963             from pandas.core.groupby.grouper import get_grouper
#     964
# --> 965             grouper, exclusions, obj = get_grouper(
#     966                 obj,
#     967                 keys,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     886                 in_axis, level, gpr = False, gpr, None
#     887             else:
# --> 888                 raise KeyError(gpr)
#     889         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     890             # Add key to exclusions
#
# KeyError: 'cluster'

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-be26c24f3744> in <cell line: 1>()
# ----> 1 nltk.download('punkt')
#       2 nltk.download('stopwords')
#
# NameError: name 'nltk' is not defined

# %%
from collections import Counter
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string

# Download NLTK resources
nltk.download('punkt')
nltk.download('stopwords')

# Function to preprocess text
def preprocess_text(text):
    # Tokenize text
    tokens = word_tokenize(text)

    # Convert to lowercase
    tokens = [token.lower() for token in tokens]

    # Remove punctuation
    tokens = [token for token in tokens if token not in string.punctuation]

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]

    return tokens

# Initialize a dictionary to store frequent words for each cluster
cluster_frequent_words = {}

# For each unique_id (cluster)
for unique_id in data['unique_id'].unique():
    # Filter DataFrame to include only rows belonging to this cluster
    cluster_df = data[data['unique_id'] == unique_id]

    # Extract text data (reviews) from the filtered DataFrame
    reviews_text = cluster_df['Review']

    # Concatenate reviews into a single string
    text_combined = ' '.join(reviews_text)

    # Preprocess the text data
    tokens = preprocess_text(text_combined)

    # Count the occurrences of each word
    word_counts = Counter(tokens)

    # Get the most frequent words
    frequent_words = word_counts.most_common(10)  # Adjust 10 to get more or fewer words

    # Store the frequent words for this cluster
    cluster_frequent_words[unique_id] = frequent_words

# Print frequent words for each cluster
for unique_id, frequent_words in cluster_frequent_words.items():
    label = data
    print(f"Cluster {label} frequent words: {frequent_words}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Cluster                Author                 Date  Rating  \
# 18          Ken Quale             22/05/18     5.0
# 20           Nick Faz             07/10/19     5.0
# 21       Gyula Huszar             23/10/19     5.0
# 22         Ingrid Suy             02/12/19     5.0
# 23      Michael Allen             03/12/19     5.0
# ..                ...                  ...     ...
# 730        Dawn Wildt  2023-01-06 13:37:32     1.0
# 731       Justin Hood  2023-03-11 23:16:44     1.0
# 732  Dominique Lamont  2023-04-29 19:15:12     1.0
# 733    Adria Anderson  2023-09-20 11:20:17     1.0
# 734      John Dushane  2024-01-08 09:23:51     1.0
#
#                                                 Review         City Sentiment  \
# 18   Robin Blue is our Unifirst rep. She is fantast...       Boston  positive
# 20   Service has been great since the beginning! Wa...       Boston  positive
# 21   I've been with UniFirst for the last 20 years ...       Boston  positive
# 22   I am the assistant manager of Applus Technolog...       Boston  positive
# 23   Mike is one of the most professional individua...       Boston  positive
# ..                                                 ...          ...       ...
# 730  Worst customer service ever. Repeatedly get bi...  Indianpolis  negative
# 731  Terrible. I have till today to use my work all...  Indianpolis  negative
# 732  I was just wrongfully terminated! Banner on th...  Indianpolis  negative
# 733  Unifirst has the worst customer service I have...  Indianpolis  negative
# 734  Do your homework before using this company. Th...  Indianpolis  negative
#
#                     label  unique_id
# 18          2018_positive          0
# 20          2019_positive          1
# 21          2019_positive          1
# 22          2019_positive          1
# 23          2019_positive          1
# ..                    ...        ...
# 730         2023_negative          6
# 731  Indianpolis_negative         24
# 732         2023_negative          6
# 733         2023_negative          6
# 734         2024_negative         14
#
# [538 rows x 8 columns] frequent words: [('always', 94), ('unifirst', 74), ('service', 68), ('great', 66), ('gene', 51), ('driver', 46), ('company', 45), ('work', 43), ('job', 38), ('teo', 35)]
# Cluster                Author                 Date  Rating  \
# 18          Ken Quale             22/05/18     5.0
# 20           Nick Faz             07/10/19     5.0
# 21       Gyula Huszar             23/10/19     5.0
# 22         Ingrid Suy             02/12/19     5.0
# 23      Michael Allen             03/12/19     5.0
# ..                ...                  ...     ...
# 730        Dawn Wildt  2023-01-06 13:37:32     1.0
# 731       Justin Hood  2023-03-11 23:16:44     1.0
# 732  Dominique Lamont  2023-04-29 19:15:12     1.0
# 733    Adria Anderson  2023-09-20 11:20:17     1.0
# 734      John Dushane  2024-01-08 09:23:51     1.0
#
#                                                 Review         City Sentiment  \
# 18   Robin Blue is our Unifirst rep. She is fantast...       Boston  positive
# 20   Service has been great since the beginning! Wa...       Boston  positive
# 21   I've been with UniFirst for the last 20 years ...       Boston  positive
# 22   I am the assistant manager of Applus Technolog...       Boston  positive
# 23   Mike is one of the most professional individua...       Boston  positive
# ..                                                 ...          ...       ...
# 730  Worst customer service ever. Repeatedly get bi...  Indianpolis  negative
# 731  Terrible. I have till today to use my work all...  Indianpolis  negative
# 732  I was just wrongfully terminated! Banner on th...  Indianpolis  negative
# 733  Unifirst has the worst customer service I have...  Indianpolis  negative
# 734  Do your homework before using this company. Th...  Indianpolis  negative
#
#                     label  unique_id
# 18          2018_positive          0
# 20          2019_positive          1
# 21          2019_positive          1
# 22          2019_positive          1
# 23          2019_positive          1
# ..                    ...        ...
# 730         2023_negative          6
# 731  Indianpolis_negative         24
# 732         2023_negative          6
# 733         2023_negative          6
# 734         2024_negative         14
#
# [538 rows x 8 columns] frequent words: [('always', 55), ('great', 35), ('service', 29), ('us', 27), ('unifirst', 26), ('driver', 25), ('brandon', 25), ('robin', 24), ('care', 19), ("'s", 18)]
# Cluster                Author                 Date  Rating  \
# 18          Ken Quale             22/05/18     5.0
# 20           Nick Faz             07/10/19     5.0
# 21       Gyula Huszar             23/10/19     5.0
# 22         Ingrid Suy             02/12/19     5.0
# 23      Michael Allen             03/12/19     5.0
# ..                ...                  ...     ...
# 730        Dawn Wildt  2023-01-06 13:37:32     1.0
# 731       Justin Hood  2023-03-11 23:16:44     1.0
# 732  Dominique Lamont  2023-04-29 19:15:12     1.0
# 733    Adria Anderson  2023-09-20 11:20:17     1.0
# 734      John Dushane  2024-01-08 09:23:51     1.0
#
#                                                 Review         City Sentiment  \
# 18   Robin Blue is our Unifirst rep. She is fantast...       Boston  positive
# 20   Service has been great since the beginning! Wa...       Boston  positive
# 21   I've been with UniFirst for the last 20 years ...       Boston  positive
# 22   I am the assistant manager of Applus Technolog...       Boston  positive
# 23   Mike is one of the most professional individua...       Boston  positive
# ..                                                 ...          ...       ...
# 730  Worst customer service ever. Repeatedly get bi...  Indianpolis  negative
# 731  Terrible. I have till today to use my work all...  Indianpolis  negative
# 732  I was just wrongfully terminated! Banner on th...  Indianpolis  negative
# 733  Unifirst has the worst customer service I have...  Indianpolis  negative
# 734  Do your homework before using this company. Th...  Indianpolis  negative
#
#                     label  unique_id
# 18          2018_positive          0
# 20          2019_positive          1
# 21          2019_positive          1
# 22          2019_positive          1
# 23          2019_positive          1
# ..                    ...        ...
# 730         2023_negative          6
# 731  Indianpolis_negative         24
# 732         2023_negative          6
# 733         2023_negative          6
# 734         2024_negative         14
#
# [538 rows x 8 columns] frequent words: [('great', 60), ('class', 59), ('always', 58), ('david', 36), ('service', 35), ('job', 28), ('us', 28), ('cpr', 27), ('unifirst', 26), ('trent', 24)]
# Cluster                Author                 Date  Rating  \
# 18          Ken Quale             22/05/18     5.0
# 20           Nick Faz             07/10/19     5.0
# 21       Gyula Huszar             23/10/19     5.0
# 22         Ingrid Suy             02/12/19     5.0
# 23      Michael Allen             03/12/19     5.0
# ..                ...                  ...     ...
# 730        Dawn Wildt  2023-01-06 13:37:32     1.0
# 731       Justin Hood  2023-03-11 23:16:44     1.0
# 732  Dominique Lamont  2023-04-29 19:15:12     1.0
# 733    Adria Anderson  2023-09-20 11:20:17     1.0
# 734      John Dushane  2024-01-08 09:23:51     1.0
#
#                                                 Review         City Sentiment  \
# 18   Robin Blue is our Unifirst rep. She is fantast...       Boston  positive
# 20   Service has been great since the beginning! Wa...       Boston  positive
# 21   I've been with UniFirst for the last 20 years ...       Boston  positive
# 22   I am the assistant manager of Applus Technolog...       Boston  positive
# 23   Mike is one of the most professional individua...       Boston  positive
# ..                                                 ...          ...       ...
# 730  Worst customer service ever. Repeatedly get bi...  Indianpolis  negative
# 731  Terrible. I have till today to use my work all...  Indianpolis  negative
# 732  I was just wrongfully terminated! Banner on th...  Indianpolis  negative
# 733  Unifirst has the worst customer service I have...  Indianpolis  negative
# 734  Do your homework before using this company. Th...  Indianpolis  negative
#
#                     label  unique_id
# 18          2018_positive          0
# 20          2019_positive          1
# 21          2019_positive          1
# 22          2019_positive          1
# 23          2019_positive          1
# ..                    ...        ...
# 730         2023_negative          6
# 731  Indianpolis_negative         24
# 732         2023_negative          6
# 733         2023_negative          6
# 734         2024_negative         14
#
# [538 rows x 8 columns] frequent words: [('service', 6), ('bad', 5), ('uniforms', 4), ('call', 4), ('manager', 4), ('’', 4), ('time', 3), ('yet', 3), ('receive', 3), ('delivered', 3)]
# Cluster                Author                 Date  Rating  \
# 18          Ken Quale             22/05/18     5.0
# 20           Nick Faz             07/10/19     5.0
# 21       Gyula Huszar             23/10/19     5.0
# 22         Ingrid Suy             02/12/19     5.0
# 23      Michael Allen             03/12/19     5.0
# ..                ...                  ...     ...
# 730        Dawn Wildt  2023-01-06 13:37:32     1.0
# 731       Justin Hood  2023-03-11 23:16:44     1.0
# 732  Dominique Lamont  2023-04-29 19:15:12     1.0
# 733    Adria Anderson  2023-09-20 11:20:17     1.0
# 734      John Dushane  2024-01-08 09:23:51     1.0
#
#                                                 Review         City Sentiment  \
# 18   Robin Blue is our Unifirst rep. She is fantast...       Boston  positive
# 20   Service has been great since the beginning! Wa...       Boston  positive
# 21   I've been with UniFirst for the last 20 years ...       Boston  positive
# 22   I am the assistant manager of Applus Technolog...       Boston  positive
# 23   Mike is one of the most professional individua...       Boston  positive
# ..                                                 ...          ...       ...
# 730  Worst customer service ever. Repeatedly get bi...  Indianpolis  negative
# 731  Terrible. I have till today to use my work all...  Indianpolis  negative
# 732  I was just wrongfully terminated! Banner on th...  Indianpolis  negative
# 733  Unifirst has the worst customer service I have...  Indianpolis  negative
# 734  Do your homework before using this company. Th...  Indianpolis  negative
#
#                     label  unique_id
# 18          2018_positive          0
# 20          2019_positive          1
# 21          2019_positive          1
# 22          2019_positive          1
# 23          2019_positive          1
# ..                    ...        ...
# 730         2023_negative          6
# 731  Indianpolis_negative         24
# 732         2023_negative          6
# 733         2023_negative          6
# 734         2024_negative         14
#
# [538 rows x 8 columns] frequent words: [('great', 31), ('service', 21), ('company', 16), ('unifirst', 16), ('always', 15), ('job', 13), ('recommend', 11), ('lucas', 11), ('uniform', 10), ('driver', 9)]
# Cluster                Author                 Date  Rating  \
# 18          Ken Quale             22/05/18     5.0
# 20           Nick Faz             07/10/19     5.0
# 21       Gyula Huszar             23/10/19     5.0
# 22         Ingrid Suy             02/12/19     5.0
# 23      Michael Allen             03/12/19     5.0
# ..                ...                  ...     ...
# 730        Dawn Wildt  2023-01-06 13:37:32     1.0
# 731       Justin Hood  2023-03-11 23:16:44     1.0
# 732  Dominique Lamont  2023-04-29 19:15:12     1.0
# 733    Adria Anderson  2023-09-20 11:20:17     1.0
# 734      John Dushane  2024-01-08 09:23:51     1.0
#
#                                                 Review         City Sentiment  \
# 18   Robin Blue is our Unifirst rep. She is fantast...       Boston  positive
# 20   Service has been great since the beginning! Wa...       Boston  positive
# 21   I've been with UniFirst for the last 20 years ...       Boston  positive
# 22   I am the assistant manager of Applus Technolog...       Boston  positive
# 23   Mike is one of the most professional individua...       Boston  positive
# ..                                                 ...          ...       ...
# 730  Worst customer service ever. Repeatedly get bi...  Indianpolis  negative
# 731  Terrible. I have till today to use my work all...  Indianpolis  negative
# 732  I was just wrongfully terminated! Banner on th...  Indianpolis  negative
# 733  Unifirst has the worst customer service I have...  Indianpolis  negative
# 734  Do your homework before using this company. Th...  Indianpolis  negative
#
#                     label  unique_id
# 18          2018_positive          0
# 20          2019_positive          1
# 21          2019_positive          1
# 22          2019_positive          1
# 23          2019_positive          1
# ..                    ...        ...
# 730         2023_negative          6
# 731  Indianpolis_negative         24
# 732         2023_negative          6
# 733         2023_negative          6
# 734         2024_negative         14
#
# [538 rows x 8 columns] frequent words: [('company', 11), ('unifirst', 9), ('service', 9), ('uniforms', 8), ('would', 7), ('never', 6), ("n't", 5), ('even', 5), ('business', 4), ('items', 4)]
# Cluster                Author                 Date  Rating  \
# 18          Ken Quale             22/05/18     5.0
# 20           Nick Faz             07/10/19     5.0
# 21       Gyula Huszar             23/10/19     5.0
# 22         Ingrid Suy             02/12/19     5.0
# 23      Michael Allen             03/12/19     5.0
# ..                ...                  ...     ...
# 730        Dawn Wildt  2023-01-06 13:37:32     1.0
# 731       Justin Hood  2023-03-11 23:16:44     1.0
# 732  Dominique Lamont  2023-04-29 19:15:12     1.0
# 733    Adria Anderson  2023-09-20 11:20:17     1.0
# 734      John Dushane  2024-01-08 09:23:51     1.0
#
#                                                 Review         City Sentiment  \
# 18   Robin Blue is our Unifirst rep. She is fantast...       Boston  positive
# 20   Service has been great since the beginning! Wa...       Boston  positive
# 21   I've been with UniFirst for the last 20 years ...       Boston  positive
# 22   I am the assistant manager of Applus Technolog...       Boston  positive
# 23   Mike is one of the most professional individua...       Boston  positive
# ..                                                 ...          ...       ...
# 730  Worst customer service ever. Repeatedly get bi...  Indianpolis  negative
# 731  Terrible. I have till today to use my work all...  Indianpolis  negative
# 732  I was just wrongfully terminated! Banner on th...  Indianpolis  negative
# 733  Unifirst has the worst customer service I have...  Indianpolis  negative
# 734  Do your homework before using this company. Th...  Indianpolis  negative
#
#                     label  unique_id
# 18          2018_positive          0
# 20          2019_positive          1
# 21          2019_positive          1
# 22          2019_positive          1
# 23          2019_positive          1
# ..                    ...        ...
# 730         2023_negative          6
# 731  Indianpolis_negative         24
# 732         2023_negative          6
# 733         2023_negative          6
# 734         2024_negative         14
#
# [538 rows x 8 columns] frequent words: [('service', 9), ('’', 7), ('uniforms', 7), ('would', 6), ('company', 6), ("n't", 6), ('time', 6), ('ever', 6), ('us', 6), ('told', 5)]
# Cluster                Author                 Date  Rating  \
# 18          Ken Quale             22/05/18     5.0
# 20           Nick Faz             07/10/19     5.0
# 21       Gyula Huszar             23/10/19     5.0
# 22         Ingrid Suy             02/12/19     5.0
# 23      Michael Allen             03/12/19     5.0
# ..                ...                  ...     ...
# 730        Dawn Wildt  2023-01-06 13:37:32     1.0
# 731       Justin Hood  2023-03-11 23:16:44     1.0
# 732  Dominique Lamont  2023-04-29 19:15:12     1.0
# 733    Adria Anderson  2023-09-20 11:20:17     1.0
# 734      John Dushane  2024-01-08 09:23:51     1.0
#
#                                                 Review         City Sentiment  \
# 18   Robin Blue is our Unifirst rep. She is fantast...       Boston  positive
# 20   Service has been great since the beginning! Wa...       Boston  positive
# 21   I've been with UniFirst for the last 20 years ...       Boston  positive
# 22   I am the assistant manager of Applus Technolog...       Boston  positive
# 23   Mike is one of the most professional individua...       Boston  positive
# ..                                                 ...          ...       ...
# 730  Worst customer service ever. Repeatedly get bi...  Indianpolis  negative
# 731  Terrible. I have till today to use my work all...  Indianpolis  negative
# 732  I was just wrongfully terminated! Banner on th...  Indianpolis  negative
# 733  Unifirst has the worst customer service I have...  Indianpolis  negative
# 734  Do your homework before using this company. Th...  Indianpolis  negative
#
#                     label  unique_id
# 18          2018_positive          0
# 20          2019_positive          1
# 21          2019_positive          1
# 22          2019_positive          1
# 23          2019_positive          1
# ..                    ...        ...
# 730         2023_negative          6
# 731  Indianpolis_negative         24
# 732         2023_negative          6
# 733         2023_negative          6
# 734         2024_negative         14
#
# [538 rows x 8 columns] frequent words: [('eb', 25), ('class', 23), ('training', 15), ('informative', 10), ('great', 10), ('fun', 10), ('work', 6), ('first', 6), ('https', 6), ('made', 6)]
# Cluster                Author                 Date  Rating  \
# 18          Ken Quale             22/05/18     5.0
# 20           Nick Faz             07/10/19     5.0
# 21       Gyula Huszar             23/10/19     5.0
# 22         Ingrid Suy             02/12/19     5.0
# 23      Michael Allen             03/12/19     5.0
# ..                ...                  ...     ...
# 730        Dawn Wildt  2023-01-06 13:37:32     1.0
# 731       Justin Hood  2023-03-11 23:16:44     1.0
# 732  Dominique Lamont  2023-04-29 19:15:12     1.0
# 733    Adria Anderson  2023-09-20 11:20:17     1.0
# 734      John Dushane  2024-01-08 09:23:51     1.0
#
#                                                 Review         City Sentiment  \
# 18   Robin Blue is our Unifirst rep. She is fantast...       Boston  positive
# 20   Service has been great since the beginning! Wa...       Boston  positive
# 21   I've been with UniFirst for the last 20 years ...       Boston  positive
# 22   I am the assistant manager of Applus Technolog...       Boston  positive
# 23   Mike is one of the most professional individua...       Boston  positive
# ..                                                 ...          ...       ...
# 730  Worst customer service ever. Repeatedly get bi...  Indianpolis  negative
# 731  Terrible. I have till today to use my work all...  Indianpolis  negative
# 732  I was just wrongfully terminated! Banner on th...  Indianpolis  negative
# 733  Unifirst has the worst customer service I have...  Indianpolis  negative
# 734  Do your homework before using this company. Th...  Indianpolis  negative
#
#                     label  unique_id
# 18          2018_positive          0
# 20          2019_positive          1
# 21          2019_positive          1
# 22          2019_positive          1
# 23          2019_positive          1
# ..                    ...        ...
# 730         2023_negative          6
# 731  Indianpolis_negative         24
# 732         2023_negative          6
# 733         2023_negative          6
# 734         2024_negative         14
#
# [538 rows x 8 columns] frequent words: [('class', 7), ('eb', 7), ('also', 5), ('training', 5), ('kept', 5), ('https', 4), ('excellent', 4), ('time', 4), ('great', 4), ('highly', 4)]
# Cluster                Author                 Date  Rating  \
# 18          Ken Quale             22/05/18     5.0
# 20           Nick Faz             07/10/19     5.0
# 21       Gyula Huszar             23/10/19     5.0
# 22         Ingrid Suy             02/12/19     5.0
# 23      Michael Allen             03/12/19     5.0
# ..                ...                  ...     ...
# 730        Dawn Wildt  2023-01-06 13:37:32     1.0
# 731       Justin Hood  2023-03-11 23:16:44     1.0
# 732  Dominique Lamont  2023-04-29 19:15:12     1.0
# 733    Adria Anderson  2023-09-20 11:20:17     1.0
# 734      John Dushane  2024-01-08 09:23:51     1.0
#
#                                                 Review         City Sentiment  \
# 18   Robin Blue is our Unifirst rep. She is fantast...       Boston  positive
# 20   Service has been great since the beginning! Wa...       Boston  positive
# 21   I've been with UniFirst for the last 20 years ...       Boston  positive
# 22   I am the assistant manager of Applus Technolog...       Boston  positive
# 23   Mike is one of the most professional individua...       Boston  positive
# ..                                                 ...          ...       ...
# 730  Worst customer service ever. Repeatedly get bi...  Indianpolis  negative
# 731  Terrible. I have till today to use my work all...  Indianpolis  negative
# 732  I was just wrongfully terminated! Banner on th...  Indianpolis  negative
# 733  Unifirst has the worst customer service I have...  Indianpolis  negative
# 734  Do your homework before using this company. Th...  Indianpolis  negative
#
#                     label  unique_id
# 18          2018_positive          0
# 20          2019_positive          1
# 21          2019_positive          1
# 22          2019_positive          1
# 23          2019_positive          1
# ..                    ...        ...
# 730         2023_negative          6
# 731  Indianpolis_negative         24
# 732         2023_negative          6
# 733         2023_negative          6
# 734         2024_negative         14
#
# [538 rows x 8 columns] frequent words: [('charge', 4), ('never', 4), ('company', 3), ('uniform', 2), ('ever', 2), ('extra', 2), ('anyone', 2), ('uniforms', 2), ('shirts', 2), ('us', 2)]
# Cluster                Author                 Date  Rating  \
# 18          Ken Quale             22/05/18     5.0
# 20           Nick Faz             07/10/19     5.0
# 21       Gyula Huszar             23/10/19     5.0
# 22         Ingrid Suy             02/12/19     5.0
# 23      Michael Allen             03/12/19     5.0
# ..                ...                  ...     ...
# 730        Dawn Wildt  2023-01-06 13:37:32     1.0
# 731       Justin Hood  2023-03-11 23:16:44     1.0
# 732  Dominique Lamont  2023-04-29 19:15:12     1.0
# 733    Adria Anderson  2023-09-20 11:20:17     1.0
# 734      John Dushane  2024-01-08 09:23:51     1.0
#
#                                                 Review         City Sentiment  \
# 18   Robin Blue is our Unifirst rep. She is fantast...       Boston  positive
# 20   Service has been great since the beginning! Wa...       Boston  positive
# 21   I've been with UniFirst for the last 20 years ...       Boston  positive
# 22   I am the assistant manager of Applus Technolog...       Boston  positive
# 23   Mike is one of the most professional individua...       Boston  positive
# ..                                                 ...          ...       ...
# 730  Worst customer service ever. Repeatedly get bi...  Indianpolis  negative
# 731  Terrible. I have till today to use my work all...  Indianpolis  negative
# 732  I was just wrongfully terminated! Banner on th...  Indianpolis  negative
# 733  Unifirst has the worst customer service I have...  Indianpolis  negative
# 734  Do your homework before using this company. Th...  Indianpolis  negative
#
#                     label  unique_id
# 18          2018_positive          0
# 20          2019_positive          1
# 21          2019_positive          1
# 22          2019_positive          1
# 23          2019_positive          1
# ..                    ...        ...
# 730         2023_negative          6
# 731  Indianpolis_negative         24
# 732         2023_negative          6
# 733         2023_negative          6
# 734         2024_negative         14
#
# [538 rows x 8 columns] frequent words: [('week', 9), ('items', 9), ('service', 9), ('issues', 8), ('company', 7), ('correct', 7), ('always', 7), ('missing', 6), ('one', 6), ('customer', 6)]
# Cluster                Author                 Date  Rating  \
# 18          Ken Quale             22/05/18     5.0
# 20           Nick Faz             07/10/19     5.0
# 21       Gyula Huszar             23/10/19     5.0
# 22         Ingrid Suy             02/12/19     5.0
# 23      Michael Allen             03/12/19     5.0
# ..                ...                  ...     ...
# 730        Dawn Wildt  2023-01-06 13:37:32     1.0
# 731       Justin Hood  2023-03-11 23:16:44     1.0
# 732  Dominique Lamont  2023-04-29 19:15:12     1.0
# 733    Adria Anderson  2023-09-20 11:20:17     1.0
# 734      John Dushane  2024-01-08 09:23:51     1.0
#
#                                                 Review         City Sentiment  \
# 18   Robin Blue is our Unifirst rep. She is fantast...       Boston  positive
# 20   Service has been great since the beginning! Wa...       Boston  positive
# 21   I've been with UniFirst for the last 20 years ...       Boston  positive
# 22   I am the assistant manager of Applus Technolog...       Boston  positive
# 23   Mike is one of the most professional individua...       Boston  positive
# ..                                                 ...          ...       ...
# 730  Worst customer service ever. Repeatedly get bi...  Indianpolis  negative
# 731  Terrible. I have till today to use my work all...  Indianpolis  negative
# 732  I was just wrongfully terminated! Banner on th...  Indianpolis  negative
# 733  Unifirst has the worst customer service I have...  Indianpolis  negative
# 734  Do your homework before using this company. Th...  Indianpolis  negative
#
#                     label  unique_id
# 18          2018_positive          0
# 20          2019_positive          1
# 21          2019_positive          1
# 22          2019_positive          1
# 23          2019_positive          1
# ..                    ...        ...
# 730         2023_negative          6
# 731  Indianpolis_negative         24
# 732         2023_negative          6
# 733         2023_negative          6
# 734         2024_negative         14
#
# [538 rows x 8 columns] frequent words: [('time', 4), ('always', 4), ('every', 3), ("'s", 3), ('could', 2), ('would', 2), ('beginning', 2), ('price', 2), ('shine', 2), ('professional', 2)]
# Cluster                Author                 Date  Rating  \
# 18          Ken Quale             22/05/18     5.0
# 20           Nick Faz             07/10/19     5.0
# 21       Gyula Huszar             23/10/19     5.0
# 22         Ingrid Suy             02/12/19     5.0
# 23      Michael Allen             03/12/19     5.0
# ..                ...                  ...     ...
# 730        Dawn Wildt  2023-01-06 13:37:32     1.0
# 731       Justin Hood  2023-03-11 23:16:44     1.0
# 732  Dominique Lamont  2023-04-29 19:15:12     1.0
# 733    Adria Anderson  2023-09-20 11:20:17     1.0
# 734      John Dushane  2024-01-08 09:23:51     1.0
#
#                                                 Review         City Sentiment  \
# 18   Robin Blue is our Unifirst rep. She is fantast...       Boston  positive
# 20   Service has been great since the beginning! Wa...       Boston  positive
# 21   I've been with UniFirst for the last 20 years ...       Boston  positive
# 22   I am the assistant manager of Applus Technolog...       Boston  positive
# 23   Mike is one of the most professional individua...       Boston  positive
# ..                                                 ...          ...       ...
# 730  Worst customer service ever. Repeatedly get bi...  Indianpolis  negative
# 731  Terrible. I have till today to use my work all...  Indianpolis  negative
# 732  I was just wrongfully terminated! Banner on th...  Indianpolis  negative
# 733  Unifirst has the worst customer service I have...  Indianpolis  negative
# 734  Do your homework before using this company. Th...  Indianpolis  negative
#
#                     label  unique_id
# 18          2018_positive          0
# 20          2019_positive          1
# 21          2019_positive          1
# 22          2019_positive          1
# 23          2019_positive          1
# ..                    ...        ...
# 730         2023_negative          6
# 731  Indianpolis_negative         24
# 732         2023_negative          6
# 733         2023_negative          6
# 734         2024_negative         14
#
# [538 rows x 8 columns] frequent words: [('henry', 6), ('unifirst', 4), ('company', 4), ("'s", 4), ('service', 3), ('uniforms', 3), ('concerns', 2), ('always', 2), ('driver', 2), ('say', 2)]
# Cluster                Author                 Date  Rating  \
# 18          Ken Quale             22/05/18     5.0
# 20           Nick Faz             07/10/19     5.0
# 21       Gyula Huszar             23/10/19     5.0
# 22         Ingrid Suy             02/12/19     5.0
# 23      Michael Allen             03/12/19     5.0
# ..                ...                  ...     ...
# 730        Dawn Wildt  2023-01-06 13:37:32     1.0
# 731       Justin Hood  2023-03-11 23:16:44     1.0
# 732  Dominique Lamont  2023-04-29 19:15:12     1.0
# 733    Adria Anderson  2023-09-20 11:20:17     1.0
# 734      John Dushane  2024-01-08 09:23:51     1.0
#
#                                                 Review         City Sentiment  \
# 18   Robin Blue is our Unifirst rep. She is fantast...       Boston  positive
# 20   Service has been great since the beginning! Wa...       Boston  positive
# 21   I've been with UniFirst for the last 20 years ...       Boston  positive
# 22   I am the assistant manager of Applus Technolog...       Boston  positive
# 23   Mike is one of the most professional individua...       Boston  positive
# ..                                                 ...          ...       ...
# 730  Worst customer service ever. Repeatedly get bi...  Indianpolis  negative
# 731  Terrible. I have till today to use my work all...  Indianpolis  negative
# 732  I was just wrongfully terminated! Banner on th...  Indianpolis  negative
# 733  Unifirst has the worst customer service I have...  Indianpolis  negative
# 734  Do your homework before using this company. Th...  Indianpolis  negative
#
#                     label  unique_id
# 18          2018_positive          0
# 20          2019_positive          1
# 21          2019_positive          1
# 22          2019_positive          1
# 23          2019_positive          1
# ..                    ...        ...
# 730         2023_negative          6
# 731  Indianpolis_negative         24
# 732         2023_negative          6
# 733         2023_negative          6
# 734         2024_negative         14
#
# [538 rows x 8 columns] frequent words: [('worst', 1), ('company', 1), ('time', 1), ('’', 1), ('let', 1), ('trick', 1), ('signing', 1), ('anything', 1), ('try', 1), ('sue', 1)]
# Cluster                Author                 Date  Rating  \
# 18          Ken Quale             22/05/18     5.0
# 20           Nick Faz             07/10/19     5.0
# 21       Gyula Huszar             23/10/19     5.0
# 22         Ingrid Suy             02/12/19     5.0
# 23      Michael Allen             03/12/19     5.0
# ..                ...                  ...     ...
# 730        Dawn Wildt  2023-01-06 13:37:32     1.0
# 731       Justin Hood  2023-03-11 23:16:44     1.0
# 732  Dominique Lamont  2023-04-29 19:15:12     1.0
# 733    Adria Anderson  2023-09-20 11:20:17     1.0
# 734      John Dushane  2024-01-08 09:23:51     1.0
#
#                                                 Review         City Sentiment  \
# 18   Robin Blue is our Unifirst rep. She is fantast...       Boston  positive
# 20   Service has been great since the beginning! Wa...       Boston  positive
# 21   I've been with UniFirst for the last 20 years ...       Boston  positive
# 22   I am the assistant manager of Applus Technolog...       Boston  positive
# 23   Mike is one of the most professional individua...       Boston  positive
# ..                                                 ...          ...       ...
# 730  Worst customer service ever. Repeatedly get bi...  Indianpolis  negative
# 731  Terrible. I have till today to use my work all...  Indianpolis  negative
# 732  I was just wrongfully terminated! Banner on th...  Indianpolis  negative
# 733  Unifirst has the worst customer service I have...  Indianpolis  negative
# 734  Do your homework before using this company. Th...  Indianpolis  negative
#
#                     label  unique_id
# 18          2018_positive          0
# 20          2019_positive          1
# 21          2019_positive          1
# 22          2019_positive          1
# 23          2019_positive          1
# ..                    ...        ...
# 730         2023_negative          6
# 731  Indianpolis_negative         24
# 732         2023_negative          6
# 733         2023_negative          6
# 734         2024_negative         14
#
# [538 rows x 8 columns] frequent words: [('company', 7), ('service', 5), ('us', 5), ('customer', 4), ('times', 3), ('terrible', 2), ('trying', 2), ('sue', 2), ('hate', 2), ('customers', 2)]
# Cluster                Author                 Date  Rating  \
# 18          Ken Quale             22/05/18     5.0
# 20           Nick Faz             07/10/19     5.0
# 21       Gyula Huszar             23/10/19     5.0
# 22         Ingrid Suy             02/12/19     5.0
# 23      Michael Allen             03/12/19     5.0
# ..                ...                  ...     ...
# 730        Dawn Wildt  2023-01-06 13:37:32     1.0
# 731       Justin Hood  2023-03-11 23:16:44     1.0
# 732  Dominique Lamont  2023-04-29 19:15:12     1.0
# 733    Adria Anderson  2023-09-20 11:20:17     1.0
# 734      John Dushane  2024-01-08 09:23:51     1.0
#
#                                                 Review         City Sentiment  \
# 18   Robin Blue is our Unifirst rep. She is fantast...       Boston  positive
# 20   Service has been great since the beginning! Wa...       Boston  positive
# 21   I've been with UniFirst for the last 20 years ...       Boston  positive
# 22   I am the assistant manager of Applus Technolog...       Boston  positive
# 23   Mike is one of the most professional individua...       Boston  positive
# ..                                                 ...          ...       ...
# 730  Worst customer service ever. Repeatedly get bi...  Indianpolis  negative
# 731  Terrible. I have till today to use my work all...  Indianpolis  negative
# 732  I was just wrongfully terminated! Banner on th...  Indianpolis  negative
# 733  Unifirst has the worst customer service I have...  Indianpolis  negative
# 734  Do your homework before using this company. Th...  Indianpolis  negative
#
#                     label  unique_id
# 18          2018_positive          0
# 20          2019_positive          1
# 21          2019_positive          1
# 22          2019_positive          1
# 23          2019_positive          1
# ..                    ...        ...
# 730         2023_negative          6
# 731  Indianpolis_negative         24
# 732         2023_negative          6
# 733         2023_negative          6
# 734         2024_negative         14
#
# [538 rows x 8 columns] frequent words: [('till', 2), ('terrible', 1), ('today', 1), ('use', 1), ('work', 1), ('allowance', 1), ('yes', 1), ("n't", 1), ('waited', 1), ('last', 1)]

# %%
for unique_id, frequent_words in cluster_frequent_words.items():
    # Get the label corresponding to the unique_id from the data DataFrame
    label = data[data['unique_id'] == unique_id]['label'].iloc[0]

    # Print the label and frequent words
    print(f"Cluster {label} frequent words: {frequent_words}")
# Out:
# Cluster 2018_positive frequent words: [('always', 94), ('unifirst', 74), ('service', 68), ('great', 66), ('gene', 51), ('driver', 46), ('company', 45), ('work', 43), ('job', 38), ('teo', 35)]
# Cluster 2019_positive frequent words: [('always', 55), ('great', 35), ('service', 29), ('us', 27), ('unifirst', 26), ('driver', 25), ('brandon', 25), ('robin', 24), ('care', 19), ("'s", 18)]
# Cluster 2021_positive frequent words: [('great', 60), ('class', 59), ('always', 58), ('david', 36), ('service', 35), ('job', 28), ('us', 28), ('cpr', 27), ('unifirst', 26), ('trent', 24)]
# Cluster 2019_negative frequent words: [('service', 6), ('bad', 5), ('uniforms', 4), ('call', 4), ('manager', 4), ('’', 4), ('time', 3), ('yet', 3), ('receive', 3), ('delivered', 3)]
# Cluster 2020_positive frequent words: [('great', 31), ('service', 21), ('company', 16), ('unifirst', 16), ('always', 15), ('job', 13), ('recommend', 11), ('lucas', 11), ('uniform', 10), ('driver', 9)]
# Cluster 2022_negative frequent words: [('company', 11), ('unifirst', 9), ('service', 9), ('uniforms', 8), ('would', 7), ('never', 6), ("n't", 5), ('even', 5), ('business', 4), ('items', 4)]
# Cluster 2023_negative frequent words: [('service', 9), ('’', 7), ('uniforms', 7), ('would', 6), ('company', 6), ("n't", 6), ('time', 6), ('ever', 6), ('us', 6), ('told', 5)]
# Cluster 2022_positive frequent words: [('eb', 25), ('class', 23), ('training', 15), ('informative', 10), ('great', 10), ('fun', 10), ('work', 6), ('first', 6), ('https', 6), ('made', 6)]
# Cluster 2023_positive frequent words: [('class', 7), ('eb', 7), ('also', 5), ('training', 5), ('kept', 5), ('https', 4), ('excellent', 4), ('time', 4), ('great', 4), ('highly', 4)]
# Cluster 2023_neutral frequent words: [('charge', 4), ('never', 4), ('company', 3), ('uniform', 2), ('ever', 2), ('extra', 2), ('anyone', 2), ('uniforms', 2), ('shirts', 2), ('us', 2)]
# Cluster 2020_negative frequent words: [('week', 9), ('items', 9), ('service', 9), ('issues', 8), ('company', 7), ('correct', 7), ('always', 7), ('missing', 6), ('one', 6), ('customer', 6)]
# Cluster 2021_negative frequent words: [('time', 4), ('always', 4), ('every', 3), ("'s", 3), ('could', 2), ('would', 2), ('beginning', 2), ('price', 2), ('shine', 2), ('professional', 2)]
# Cluster 2018_negative frequent words: [('henry', 6), ('unifirst', 4), ('company', 4), ("'s", 4), ('service', 3), ('uniforms', 3), ('concerns', 2), ('always', 2), ('driver', 2), ('say', 2)]
# Cluster 2024_positive frequent words: [('worst', 1), ('company', 1), ('time', 1), ('’', 1), ('let', 1), ('trick', 1), ('signing', 1), ('anything', 1), ('try', 1), ('sue', 1)]
# Cluster 2024_negative frequent words: [('company', 7), ('service', 5), ('us', 5), ('customer', 4), ('times', 3), ('terrible', 2), ('trying', 2), ('sue', 2), ('hate', 2), ('customers', 2)]
# Cluster Indianpolis_negative frequent words: [('till', 2), ('terrible', 1), ('today', 1), ('use', 1), ('work', 1), ('allowance', 1), ('yes', 1), ("n't", 1), ('waited', 1), ('last', 1)]

# %%
data.to_csv("Cleaned_Preprocessed.csv")

# %%
positive_words_freq = {}
negative_words_freq = {}

# Iterate over cluster frequent words
for unique_id, frequent_words in cluster_frequent_words.items():
    # Get the label corresponding to the unique_id from the data DataFrame
    label = data[data['unique_id'] == unique_id]['label'].iloc[0]

    # Check if label has suffix "positive" or "negative"
    if label.endswith("positive"):
        # Add words and their frequencies to the positive_words_freq dictionary
        positive_words_freq[label] = frequent_words
    elif label.endswith("negative"):
        # Add words and their frequencies to the negative_words_freq dictionary
        negative_words_freq[label] = frequent_words

# Print the dictionaries
print("Positive Words and Frequencies:")
for label, frequent_words in positive_words_freq.items():
    print(f"Cluster {label} frequent words: {frequent_words}")

print("\nNegative Words and Frequencies:")
for label, frequent_words in negative_words_freq.items():
    print(f"Cluster {label} frequent words: {frequent_words}")
# Out:
# Positive Words and Frequencies:
# Cluster 2018_positive frequent words: [('always', 94), ('unifirst', 74), ('service', 68), ('great', 66), ('gene', 51), ('driver', 46), ('company', 45), ('work', 43), ('job', 38), ('teo', 35)]
# Cluster 2019_positive frequent words: [('always', 55), ('great', 35), ('service', 29), ('us', 27), ('unifirst', 26), ('driver', 25), ('brandon', 25), ('robin', 24), ('care', 19), ("'s", 18)]
# Cluster 2021_positive frequent words: [('great', 60), ('class', 59), ('always', 58), ('david', 36), ('service', 35), ('job', 28), ('us', 28), ('cpr', 27), ('unifirst', 26), ('trent', 24)]
# Cluster 2020_positive frequent words: [('great', 31), ('service', 21), ('company', 16), ('unifirst', 16), ('always', 15), ('job', 13), ('recommend', 11), ('lucas', 11), ('uniform', 10), ('driver', 9)]
# Cluster 2022_positive frequent words: [('eb', 25), ('class', 23), ('training', 15), ('informative', 10), ('great', 10), ('fun', 10), ('work', 6), ('first', 6), ('https', 6), ('made', 6)]
# Cluster 2023_positive frequent words: [('class', 7), ('eb', 7), ('also', 5), ('training', 5), ('kept', 5), ('https', 4), ('excellent', 4), ('time', 4), ('great', 4), ('highly', 4)]
# Cluster 2024_positive frequent words: [('worst', 1), ('company', 1), ('time', 1), ('’', 1), ('let', 1), ('trick', 1), ('signing', 1), ('anything', 1), ('try', 1), ('sue', 1)]
#
# Negative Words and Frequencies:
# Cluster 2019_negative frequent words: [('service', 6), ('bad', 5), ('uniforms', 4), ('call', 4), ('manager', 4), ('’', 4), ('time', 3), ('yet', 3), ('receive', 3), ('delivered', 3)]
# Cluster 2022_negative frequent words: [('company', 11), ('unifirst', 9), ('service', 9), ('uniforms', 8), ('would', 7), ('never', 6), ("n't", 5), ('even', 5), ('business', 4), ('items', 4)]
# Cluster 2023_negative frequent words: [('service', 9), ('’', 7), ('uniforms', 7), ('would', 6), ('company', 6), ("n't", 6), ('time', 6), ('ever', 6), ('us', 6), ('told', 5)]
# Cluster 2020_negative frequent words: [('week', 9), ('items', 9), ('service', 9), ('issues', 8), ('company', 7), ('correct', 7), ('always', 7), ('missing', 6), ('one', 6), ('customer', 6)]
# Cluster 2021_negative frequent words: [('time', 4), ('always', 4), ('every', 3), ("'s", 3), ('could', 2), ('would', 2), ('beginning', 2), ('price', 2), ('shine', 2), ('professional', 2)]
# Cluster 2018_negative frequent words: [('henry', 6), ('unifirst', 4), ('company', 4), ("'s", 4), ('service', 3), ('uniforms', 3), ('concerns', 2), ('always', 2), ('driver', 2), ('say', 2)]
# Cluster 2024_negative frequent words: [('company', 7), ('service', 5), ('us', 5), ('customer', 4), ('times', 3), ('terrible', 2), ('trying', 2), ('sue', 2), ('hate', 2), ('customers', 2)]
# Cluster Indianpolis_negative frequent words: [('till', 2), ('terrible', 1), ('today', 1), ('use', 1), ('work', 1), ('allowance', 1), ('yes', 1), ("n't", 1), ('waited', 1), ('last', 1)]

# %%
import matplotlib.pyplot as plt

# Initialize lists to store positive and negative word frequencies and labels
positive_frequencies = []
negative_frequencies = []
labels = []

# Iterate over positive word frequencies
for label, frequent_words in positive_words_freq.items():
    positive_frequencies.append(sum(freq for _, freq in frequent_words))  # Sum of frequencies for positive words
    labels.append(label)

# Iterate over negative word frequencies
for label, frequent_words in negative_words_freq.items():
    negative_frequencies.append(sum(freq for _, freq in frequent_words))  # Sum of frequencies for negative words

# Make sure both lists have the same length
max_len = max(len(positive_frequencies), len(negative_frequencies))
positive_frequencies += [0] * (max_len - len(positive_frequencies))
negative_frequencies += [0] * (max_len - len(negative_frequencies))

# Create bar chart
x = range(max_len)
width = 0.35

fig, ax = plt.subplots()
ax.bar(x, positive_frequencies, width, label='Positive')
ax.bar(x, negative_frequencies, width, label='Negative', bottom=positive_frequencies)

ax.set_xlabel('Clusters')
ax.set_ylabel('Frequency')
ax.set_title('Frequency of Positive and Negative Words for Each Cluster')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-7782faa8b631> in <cell line: 34>()
#      32 ax.set_title('Frequency of Positive and Negative Words for Each Cluster')
#      33 ax.set_xticks(x)
# ---> 34 ax.set_xticklabels(labels)
#      35 ax.legend()
#      36
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      72
#      73         def wrapper(self, *args, **kwargs):
# ---> 74             return get_method(self)(*args, **kwargs)
#      75
#      76         wrapper.__module__ = owner.__module__
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     295                 f"for the old name will be dropped %(removal)s.")
#     296             kwargs[new] = kwargs.pop(old)
# --> 297         return func(*args, **kwargs)
#     298
#     299     # wrapper() must keep the same documented signature as func(): if we
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    1967             # remove all tick labels, so only error for > 0 labels
#    1968             if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 1969                 raise ValueError(
#    1970                     "The number of FixedLocator locations"
#    1971                     f" ({len(locator.locs)}), usually from a call to"
#
# ValueError: The number of FixedLocator locations (8), usually from a call to set_ticks, does not match the number of labels (7).
